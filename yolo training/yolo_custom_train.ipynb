# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/My Drive/yologg'

# %%
# !unzip '/content/drive/My Drive/yologg/custom_data/train_data.zip' -d '/content/drive/My Drive/yologg/custom_data'

# %%
# !unzip '/content/drive/My Drive/yologg/custom_data/test_data.zip' -d '/content/drive/My Drive/yologg/custom_data'

# %%
# !unzip '/content/drive/My Drive/yologg/custom_data/valid_data.zip' -d '/content/drive/My Drive/yologg/custom_data'

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yologg/darknet'

# %%
# %cd '/content/drive/My Drive/yologg/darknet'
# Out:
# /content/drive/My Drive/yologg/darknet

# %%
# !ls

# %%
# !sed -i 's/OPENCV=0/OPENCV=1' Makefile
# !sed -i 's/GPU=0/GPU=1' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1' Makefile
# !make
# Out:
# sed: -e expression #1, char 19: unterminated `s' command
# sed: -e expression #1, char 13: unterminated `s' command
# sed: -e expression #1, char 17: unterminated `s' command
# chmod +x *.sh

# %%
# %cd '/content/drive/My Drive/yologg'
# Out:
# /content/drive/My Drive/yologg

# %%
# !python /content/drive/MyDrive/yologg/custom_data/creating-files-data-and-name.py

# %%
# !python /content/drive/MyDrive/yologg/custom_data/creating-train-and-test-txt-files.py

# %%
# !chmod +x ./darknet/darknet

# %%
# %cd '/content/drive/My Drive/yologg'
# Out:
# /content/drive/My Drive/yologg

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov4-tiny_custom_drone.cfg backup_old/yolov4-tiny_custom_drone_last.weights -dont_show -clear
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 1462192, rewritten_bbox = 1.973886 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.000000), count: 1, class_loss = 0.000716, iou_loss = 0.000000, total_loss = 0.000716
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.774967), count: 37, class_loss = 2.025800, iou_loss = 27.859455, total_loss = 29.885256
#  total_bbox = 1462229, rewritten_bbox = 1.973904 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.897574), count: 1, class_loss = 0.001346, iou_loss = 0.193612, total_loss = 0.194958
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.775622), count: 49, class_loss = 2.464674, iou_loss = 45.275394, total_loss = 47.740067
#  total_bbox = 1462279, rewritten_bbox = 1.973974 %
# ...

# %%
# !darknet/darknet detector test custom_data/labelled_data.data darknet/cfg/yolov4-tiny_custom_drone.cfg backup_old/yolov4-tiny_custom_drone_final.weights custom_data/valid_data/0000021_00000_d_0000001.jpg
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# Cannot load image data/labels/53_0.png
# ...

# %%
# !nvidia-smi
# Out:
# Mon Jul  5 16:02:33 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
